# %%
import requests
import pandas as pd
import numpy as np
from geopy.geocoders import Nominatim
from IPython.display import Image 
from IPython.core.display import HTML 
from pandas.io.json import json_normalize
import folium

# %%
ClIENT_ID = 'KL3RTTROV0N33KJKSUK0MKY4D12LIQDWUIOHX10M4OBHVH34'
ClIENT_SECRET = 'P45QAU0PNKG4WX1PVNVTGZUP2ZU1ZRNYAMA33HJKSQZJUBF1'
VERSION = '20180604'
LIMIT =30
print('Your credentails:')
print('Foursquare_ID: ' + ClIENT_ID)

print('Foursquare_Secret:' + ClIENT_SECRET)
# Out:
# Your credentails:
# Foursquare_ID: KL3RTTROV0N33KJKSUK0MKY4D12LIQDWUIOHX10M4OBHVH34
# Foursquare_Secret:P45QAU0PNKG4WX1PVNVTGZUP2ZU1ZRNYAMA33HJKSQZJUBF1

# %%
#define city location, latitude, longitude
city = 'Mumbai'
geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(city)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 18.9387711 72.8353355

# %%
#searching hotels

# %%
# search for hotels
search_query = 'Hotel'
radius = 500

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KL3RTTROV0N33KJKSUK0MKY4D12LIQDWUIOHX10M4OBHVH34&client_secret=P45QAU0PNKG4WX1PVNVTGZUP2ZU1ZRNYAMA33HJKSQZJUBF1&ll=18.9387711,72.8353355&v=20180604&query=Hotel&radius=500&limit=30'

# %%
# Sending the GET Request
results = requests.get(url).json()
#if you want to see json file then print results

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                   name  \
# 0  4e135a03a809291902c7d32f  Hotel Traveller’s Inn
# 1  4bcf4de40ffdce72215fb2c0        Residency Hotel
# 2  4cbc460f9552b60c8d81e48b      City Palace Hotel
# 3  4ffaf206e4b0a0306dd1271d      Hotel City Palace
# 4  5321eed6498e273e35971c04            sheel hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f8931735', 'name': 'B...  v-1590405162    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590405162    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590405162    False
# 3                                                 []  v-1590405162    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590405162    False
#
#                                     location.address  \
# 0                               26, ADI Marzban Path
# 1  26, Corner of D.N. Road and Rustom Sidhwa Marg...
# 2                                                NaN
# 3                                           Near CST
# 4                                                NaN
#
#                           location.crossStreet  location.lat  location.lng  \
# 0  Behind Cafe Universal, Ballard Estate, Fort     18.936039     72.838000
# 1                                          NaN     18.934978     72.833481
# 2                                          NaN     18.938970     72.835610
# 3                                          NaN     18.938474     72.834599
# 4                                          NaN     18.938211     72.835725
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.93603902855253...                413
# 1  [{'label': 'display', 'lat': 18.93497786680689...                465
# 2  [{'label': 'display', 'lat': 18.93897, 'lng': ...                 36
# 3  [{'label': 'display', 'lat': 18.93847362379592...                 84
# 4  [{'label': 'display', 'lat': 18.93821144054106...                 74
#
#   location.postalCode location.cc location.city location.state  \
# 0              400001          IN        Mumbai    Mahārāshtra
# 1              400001          IN        Mumbai    Mahārāshtra
# 2                 NaN          IN           NaN            NaN
# 3                 NaN          IN        Mumbai    Mahārāshtra
# 4                 NaN          IN           NaN            NaN
#
#   location.country                          location.formattedAddress
# 0            India  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 1            India  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 2            India                                            [India]
# 3            India             [Near CST, Mumbai, Mahārāshtra, India]
# 4            India                                            [India]

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                   name  \
# 0  4e135a03a809291902c7d32f  Hotel Traveller’s Inn
# 1  4bcf4de40ffdce72215fb2c0        Residency Hotel
# 2  4cbc460f9552b60c8d81e48b      City Palace Hotel
# 3  4ffaf206e4b0a0306dd1271d      Hotel City Palace
# 4  5321eed6498e273e35971c04            sheel hotel
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d1f8931735', 'name': 'B...  v-1590405162    False
# 1  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590405162    False
# 2  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590405162    False
# 3                                                 []  v-1590405162    False
# 4  [{'id': '4bf58dd8d48988d1fa931735', 'name': 'H...  v-1590405162    False
#
#                                     location.address  \
# 0                               26, ADI Marzban Path
# 1  26, Corner of D.N. Road and Rustom Sidhwa Marg...
# 2                                                NaN
# 3                                           Near CST
# 4                                                NaN
#
#                           location.crossStreet  location.lat  location.lng  \
# 0  Behind Cafe Universal, Ballard Estate, Fort     18.936039     72.838000
# 1                                          NaN     18.934978     72.833481
# 2                                          NaN     18.938970     72.835610
# 3                                          NaN     18.938474     72.834599
# 4                                          NaN     18.938211     72.835725
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.93603902855253...                413
# 1  [{'label': 'display', 'lat': 18.93497786680689...                465
# 2  [{'label': 'display', 'lat': 18.93897, 'lng': ...                 36
# 3  [{'label': 'display', 'lat': 18.93847362379592...                 84
# 4  [{'label': 'display', 'lat': 18.93821144054106...                 74
#
#   location.postalCode location.cc location.city location.state  \
# 0              400001          IN        Mumbai    Mahārāshtra
# 1              400001          IN        Mumbai    Mahārāshtra
# 2                 NaN          IN           NaN            NaN
# 3                 NaN          IN        Mumbai    Mahārāshtra
# 4                 NaN          IN           NaN            NaN
#
#   location.country                          location.formattedAddress
# 0            India  [26, ADI Marzban Path (Behind Cafe Universal, ...
# 1            India  [26, Corner of D.N. Road and Rustom Sidhwa Mar...
# 2            India                                            [India]
# 3            India             [Near CST, Mumbai, Mahārāshtra, India]
# 4            India                                            [India]

# %%
#cleaning

# %%
# keep only columns that include venue name, and anything that is associated with location
clean_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')]+ ['id']
clean_dataframe = dataframe.loc[:,clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
clean_dataframe['categories'] = clean_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_dataframe.columns = [column.split('.')[-1] for column in clean_dataframe.columns]

clean_dataframe.head()
# Out:
#                     name       categories  \
# 0  Hotel Traveller’s Inn  Bed & Breakfast
# 1        Residency Hotel            Hotel
# 2      City Palace Hotel            Hotel
# 3      Hotel City Palace             None
# 4            sheel hotel            Hotel
#
#                                              address  \
# 0                               26, ADI Marzban Path
# 1  26, Corner of D.N. Road and Rustom Sidhwa Marg...
# 2                                                NaN
# 3                                           Near CST
# 4                                                NaN
#
#                                    crossStreet        lat        lng  \
# 0  Behind Cafe Universal, Ballard Estate, Fort  18.936039  72.838000
# 1                                          NaN  18.934978  72.833481
# 2                                          NaN  18.938970  72.835610
# 3                                          NaN  18.938474  72.834599
# 4                                          NaN  18.938211  72.835725
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 18.93603902855253...       413     400001  IN
# 1  [{'label': 'display', 'lat': 18.93497786680689...       465     400001  IN
# 2  [{'label': 'display', 'lat': 18.93897, 'lng': ...        36        NaN  IN
# 3  [{'label': 'display', 'lat': 18.93847362379592...        84        NaN  IN
# 4  [{'label': 'display', 'lat': 18.93821144054106...        74        NaN  IN
#
#      city        state country  \
# 0  Mumbai  Mahārāshtra   India
# 1  Mumbai  Mahārāshtra   India
# 2     NaN          NaN   India
# 3  Mumbai  Mahārāshtra   India
# 4     NaN          NaN   India
#
#                                     formattedAddress                        id
# 0  [26, ADI Marzban Path (Behind Cafe Universal, ...  4e135a03a809291902c7d32f
# 1  [26, Corner of D.N. Road and Rustom Sidhwa Mar...  4bcf4de40ffdce72215fb2c0
# 2                                            [India]  4cbc460f9552b60c8d81e48b
# 3             [Near CST, Mumbai, Mahārāshtra, India]  4ffaf206e4b0a0306dd1271d
# 4                                            [India]  5321eed6498e273e35971c04

# %%
# delete unnecessary columns
clean_dataframe2= clean_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress','labeledLatLngs', 'id'], axis=1)
clean_dataframe2
# Out:
#                         name                                categories  \
# 0      Hotel Traveller’s Inn                           Bed & Breakfast
# 1            Residency Hotel                                     Hotel
# 2          City Palace Hotel                                     Hotel
# 3          Hotel City Palace                                      None
# 4                sheel hotel                                     Hotel
# 5       Hotel Fountain Plaza                         Indian Restaurant
# 6               hotel kalapi                                     Motel
# 7        Hotel Landmark Fort                           Bed & Breakfast
# 8         Colaba Grand Hotel                                 Hotel Bar
# 9      Hotel Landmark Annexe                                     Hotel
# 10             Hotel Windsor                                    Hostel
# 11        Hotel Ankitakshita                                     Hotel
# 12            Hotel Arkshita                               Snack Place
# 13        Hotel Anand Bhuvan                      Fast Food Restaurant
# 14              Hotel Ashoka                         Indian Restaurant
# 15              Hotel Outram                                     Hotel
# 16             Hotel Dolphin                                     Hotel
# 17             Welcome Hotel                                     Motel
# 18     landmark hotel mumbai  Residential Building (Apartment / Condo)
# 19    hotel golden palm fort                                Hotel Pool
# 20              Deluxe Hotel                       Housing Development
# 21            Benazeer Hotel                                     Hotel
# 22  A.k. International Hotel                                     Hotel
# 23              Cenora Hotel                          Asian Restaurant
# 24           Whatson's Hotel                                     Hotel
# 25      Mumbai Hotels, India                                     Hotel
# 26          New Anand Bhavan                      Fast Food Restaurant
#
#                                               address        lat        lng  \
# 0                                26, ADI Marzban Path  18.936039  72.838000
# 1   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 2                                                 NaN  18.938970  72.835610
# 3                                            Near CST  18.938474  72.834599
# 4                                                 NaN  18.938211  72.835725
# 5             panthaky house, Raghunath dadaji street  18.935671  72.834030
# 6                                                 NaN  18.938184  72.837802
# 7                                  249 P D Mello Road  18.938528  72.837998
# 8                                              Colaba  18.939656  72.836457
# 9                                                 NaN  18.938030  72.838844
# 10                                         Kumptha 10  18.936808  72.838327
# 11                                                NaN  18.935698  72.837123
# 12                                                NaN  18.935647  72.837311
# 13                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 14                                                NaN  18.942741  72.834501
# 15                                                NaN  18.936418  72.831732
# 16                                       327,SBS Road  18.934567  72.836942
# 17                        257 Shahid Bhagat Singh Rd.  18.937703  72.837467
# 18                                                NaN  18.938465  72.838217
# 19                                               Fort  18.933103  72.834628
# 20                       287 Shahid Bhagat Singh Road  18.935690  72.837398
# 21                                   16 Gunbow Street  18.935140  72.833948
# 22                                                NaN  18.935867  72.837875
# 23                                                NaN  18.934916  72.836969
# 24                                               Fort  18.934662  72.836778
# 25                                             Mumbai  18.939616  72.835665
# 26                                        Sheri House  18.934656  72.834848
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 2         NaN          NaN
# 3         NaN  Mahārāshtra
# 4         NaN          NaN
# 5         NaN  Mahārāshtra
# 6         NaN          NaN
# 7      400001  Mahārāshtra
# 8         NaN  Mahārāshtra
# 9      400001  Mahārāshtra
# 10        NaN  Mahārāshtra
# 11     400023  Mahārāshtra
# 12        NaN          NaN
# 13     400001  Mahārāshtra
# 14        NaN          NaN
# 15        NaN          NaN
# 16        NaN  Mahārāshtra
# 17        NaN  Mahārāshtra
# 18        NaN          NaN
# 19        NaN  Mahārāshtra
# 20     400001  Mahārāshtra
# 21     400001  Mahārāshtra
# 22        NaN          NaN
# 23        NaN          NaN
# 24        NaN  Mahārāshtra
# 25        NaN  Mahārāshtra
# 26     400023  Mahārāshtra

# %%
# delete rows with none values
clean_dataframe3 = clean_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_dataframe3
# Out:
#                      name            categories  \
# 0   Hotel Traveller’s Inn       Bed & Breakfast
# 1         Residency Hotel                 Hotel
# 7     Hotel Landmark Fort       Bed & Breakfast
# 13     Hotel Anand Bhuvan  Fast Food Restaurant
# 20           Deluxe Hotel   Housing Development
# 21         Benazeer Hotel                 Hotel
# 26       New Anand Bhavan  Fast Food Restaurant
#
#                                               address        lat        lng  \
# 0                                26, ADI Marzban Path  18.936039  72.838000
# 1   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 7                                  249 P D Mello Road  18.938528  72.837998
# 13                  Opposite Shahid bhagat Singh Road  18.935345  72.836884
# 20                       287 Shahid Bhagat Singh Road  18.935690  72.837398
# 21                                   16 Gunbow Street  18.935140  72.833948
# 26                                        Sheri House  18.934656  72.834848
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 7      400001  Mahārāshtra
# 13     400001  Mahārāshtra
# 20     400001  Mahārāshtra
# 21     400001  Mahārāshtra
# 26     400023  Mahārāshtra

# %%
# delete rows which its category is not Hotel or Event Space
array= ['Hotel', 'Event Space']
hotel_dataframe= clean_dataframe3.loc[clean_dataframe3['categories'].isin(array)]
hotel_dataframe
# Out:
#                name categories  \
# 1   Residency Hotel      Hotel
# 21   Benazeer Hotel      Hotel
#
#                                               address        lat        lng  \
# 1   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 21                                   16 Gunbow Street  18.935140  72.833948
#
#    postalCode        state
# 1      400001  Mahārāshtra
# 21     400001  Mahārāshtra

# %%
# delete rows which has duplicate hotel's name
df_hotels = hotel_dataframe.drop_duplicates(subset='name', keep="first")
df_hotels
# Out:
#                name categories  \
# 1   Residency Hotel      Hotel
# 21   Benazeer Hotel      Hotel
#
#                                               address        lat        lng  \
# 1   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 21                                   16 Gunbow Street  18.935140  72.833948
#
#    postalCode        state
# 1      400001  Mahārāshtra
# 21     400001  Mahārāshtra

# %%
# choose the hotel which has the same postalCode with the event space
df_hotel = df_hotels[df_hotels.postalCode == '400001']
df_hotel
# Out:
#                name categories  \
# 1   Residency Hotel      Hotel
# 21   Benazeer Hotel      Hotel
#
#                                               address        lat        lng  \
# 1   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 21                                   16 Gunbow Street  18.935140  72.833948
#
#    postalCode        state
# 1      400001  Mahārāshtra
# 21     400001  Mahārāshtra

# %%
#parks

# %%
# search for Parks
search_query = 'Park'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'\
.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KL3RTTROV0N33KJKSUK0MKY4D12LIQDWUIOHX10M4OBHVH34&client_secret=P45QAU0PNKG4WX1PVNVTGZUP2ZU1ZRNYAMA33HJKSQZJUBF1&ll=18.9387711,72.8353355&v=20180604&query=Park&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
presults = requests.get(url).json()
#presults

# %%
 #assign relevant part of JSON to venues
venues = presults['response']['venues']

# tranform venues into a dataframe
park_dataframe = json_normalize(venues)
park_dataframe.head()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                             name  \
# 0  511e3da9e4b092d8057a44b6  Harish Mahindra Children's Park
# 1  52f2771d11d2afc107a8206d        Traditions at Reagan Park
# 2  4c84af7ed34ca14342c74080                      Park Avenue
# 3  5b430c7f2b274a002c36a513                      Rivali Park
# 4  4c9174ec238c6dcb067ec055               Priyadarshini Park
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1590405164    False
# 1  [{'id': '5267e4d9e4b0ec79466e48c6', 'name': 'C...  v-1590405164    False
# 2  [{'id': '4bf58dd8d48988d103951735', 'name': 'C...  v-1590405164    False
# 3  [{'id': '5032885091d4c4b30a586d66', 'name': 'R...  v-1590405164    False
# 4  [{'id': '4bf58dd8d48988d163941735', 'name': 'P...  v-1590405164    False
#
#                                     location.address  location.crossStreet  \
# 0           Breach Candy, Behind American Counsulate  Bhulabhai Desai Road
# 1                                1176 Kingwood Drive                   NaN
# 2                            in High Street Phoenix,                   NaN
# 3  Rivali Park, Western Express Highway,Borivali ...                   NaN
# 4                                    Nepean Sea Road                   NaN
#
#    location.lat  location.lng  \
# 0     18.914867     72.823688
# 1     18.949804     72.834699
# 2     18.996986     72.826677
# 3     18.929599     72.828181
# 4     18.957515     72.799614
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.91486679408915...               2930
# 1  [{'label': 'display', 'lat': 18.94980408771263...               1230
# 2  [{'label': 'display', 'lat': 18.99698589447507...               6544
# 3  [{'label': 'display', 'lat': 18.92959945134227...               1268
# 4  [{'label': 'display', 'lat': 18.95751519120163...               4301
#
#   location.postalCode location.cc location.city location.state  \
# 0              400026          IN        Mumbai    Mahārāshtra
# 1               46123          IN          Avon        Indiana
# 2                 NaN          IN        Mumbai    Mahārāshtra
# 3              400066          IN           NaN    Mahārāshtra
# 4              400006          IN        Mumbai    Mahārāshtra
#
#   location.country                          location.formattedAddress  \
# 0            India  [Breach Candy, Behind American Counsulate (Bhu...
# 1            India  [1176 Kingwood Drive, Avon 46123, Indiana, India]
# 2            India  [in High Street Phoenix,, Mumbai, Mahārāshtra,...
# 3            India  [Rivali Park, Western Express Highway,Borivali...
# 4            India  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
park_clean_columns = ['name', 'categories'] + [col for col in park_dataframe.columns if col.startswith('location.')]+ ['id']
clean_park_dataframe = park_dataframe.loc[:,park_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list1 = row['categories']
    except:
        categories_list1 = row['venue.categories']
        
    if len(categories_list1) == 0:
        return None
    else:
        return categories_list1[0]['name']

# filter the category for each row
clean_park_dataframe['categories'] = clean_park_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_park_dataframe.columns = [column.split('.')[-1] for column in clean_park_dataframe.columns]

clean_park_dataframe.head()
# Out:
#                               name          categories  \
# 0  Harish Mahindra Children's Park                Park
# 1        Traditions at Reagan Park          Conference
# 2                      Park Avenue      Clothing Store
# 3                      Rivali Park  Real Estate Office
# 4               Priyadarshini Park                Park
#
#                                              address           crossStreet  \
# 0           Breach Candy, Behind American Counsulate  Bhulabhai Desai Road
# 1                                1176 Kingwood Drive                   NaN
# 2                            in High Street Phoenix,                   NaN
# 3  Rivali Park, Western Express Highway,Borivali ...                   NaN
# 4                                    Nepean Sea Road                   NaN
#
#          lat        lng                                     labeledLatLngs  \
# 0  18.914867  72.823688  [{'label': 'display', 'lat': 18.91486679408915...
# 1  18.949804  72.834699  [{'label': 'display', 'lat': 18.94980408771263...
# 2  18.996986  72.826677  [{'label': 'display', 'lat': 18.99698589447507...
# 3  18.929599  72.828181  [{'label': 'display', 'lat': 18.92959945134227...
# 4  18.957515  72.799614  [{'label': 'display', 'lat': 18.95751519120163...
#
#    distance postalCode  cc    city        state country  \
# 0      2930     400026  IN  Mumbai  Mahārāshtra   India
# 1      1230      46123  IN    Avon      Indiana   India
# 2      6544        NaN  IN  Mumbai  Mahārāshtra   India
# 3      1268     400066  IN     NaN  Mahārāshtra   India
# 4      4301     400006  IN  Mumbai  Mahārāshtra   India
#
#                                     formattedAddress                        id
# 0  [Breach Candy, Behind American Counsulate (Bhu...  511e3da9e4b092d8057a44b6
# 1  [1176 Kingwood Drive, Avon 46123, Indiana, India]  52f2771d11d2afc107a8206d
# 2  [in High Street Phoenix,, Mumbai, Mahārāshtra,...  4c84af7ed34ca14342c74080
# 3  [Rivali Park, Western Express Highway,Borivali...  5b430c7f2b274a002c36a513
# 4  [Nepean Sea Road, Mumbai 400006, Mahārāshtra, ...  4c9174ec238c6dcb067ec055

# %%
# delete unnecessary columns
clean_park_dataframe2= clean_park_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_park_dataframe2
# Out:
#                                name                                categories  \
# 0   Harish Mahindra Children's Park                                      Park
# 1         Traditions at Reagan Park                                Conference
# 2                       Park Avenue                            Clothing Store
# 3                       Rivali Park                        Real Estate Office
# 4                Priyadarshini Park                                      Park
# 5                       Park Avenue                               Men's Store
# 6          Peninsula Corporate Park                                  Building
# 7              Hotel Residency Park                                     Hotel
# 8              Hotel Residency Park                                     Hotel
# 9                  One Avighna Park                       Housing Development
# 10                     Badhwar Park                              Neighborhood
# 11              Kanha National Park                      Other Great Outdoors
# 12                     Park Shilton                                Restaurant
# 13      China Garden Shivaji Park ¤                        Chinese Restaurant
# 14                     Traffic Park                                      Park
# 15                     Badhwar Park                       Housing Development
# 16                        Park View  Residential Building (Apartment / Condo)
# 17                     Badhwar Park  Residential Building (Apartment / Condo)
# 18                      saifee park  Residential Building (Apartment / Condo)
# 19                      Bhakti Park                       Housing Development
# 20     Bhakti Park Monorail Station                        Light Rail Station
# 21           Priyadarshini Park Gym                      Gym / Fitness Center
# 22                  Land's End Park                                      Park
# 23      Amarsons Park, Breach Candy                                      Park
# 24                Park Avenue Women                             Women's Store
# 25                     Shivaji Park                                Playground
# 26                      Park Avenue                            Clothing Store
# 27                        Hill Park  Residential Building (Apartment / Condo)
# 28                       Rizvi Park  Residential Building (Apartment / Condo)
# 29                       Green park                                      None
#
#                                               address        lat        lng  \
# 0            Breach Candy, Behind American Counsulate  18.914867  72.823688
# 1                                 1176 Kingwood Drive  18.949804  72.834699
# 2                             in High Street Phoenix,  18.996986  72.826677
# 3   Rivali Park, Western Express Highway,Borivali ...  18.929599  72.828181
# 4                                     Nepean Sea Road  18.957515  72.799614
# 5   Shop No. 32/34, Churchgate House, Veer Nariman...  18.920214  72.830151
# 6                                         Lower Parel  18.998626  72.825408
# 7                                                 NaN  18.953120  72.835175
# 8                                                 NaN  18.953255  72.835320
# 9                           Mahadev Palav Marg, Parel  18.994041  72.834806
# 10                                                NaN  18.921100  72.827300
# 11                                                NaN  18.923037  72.822986
# 12                                                NaN  18.965763  72.819282
# 13             Cadell Road, Opposite Catering College  19.023244  72.835148
# 14          Cooperage Rd, Colaba, Mumbai, Maharashtra  18.918844  72.825933
# 15                                     Wodehouse Road  18.919160  72.826648
# 16                                                NaN  18.973326  72.823997
# 17                                             Colaba  18.918839  72.828051
# 18                                                NaN  18.972489  72.839654
# 19                                   Near Imax Adlabs  19.027670  72.880010
# 20                                        Bhakti Park  19.029101  72.877627
# 21                                                NaN  18.956859  72.799193
# 22                                                NaN  18.916561  72.816366
# 23                                                NaN  18.972317  72.806327
# 24                                                NaN  18.995185  72.824560
# 25                      Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 26                            Sky Zone, phoenix mills  18.995051  72.823619
# 27                                       Malabar Hill  18.951897  72.799129
# 28                                                NaN  18.967114  72.812373
# 29                                                NaN  18.947203  72.795165
#
#    postalCode           state
# 0      400026     Mahārāshtra
# 1       46123         Indiana
# 2         NaN     Mahārāshtra
# 3      400066     Mahārāshtra
# 4      400006     Mahārāshtra
# 5      400001     Mahārāshtra
# 6      400013     Mahārāshtra
# 7      400003     Mahārāshtra
# 8         NaN             NaN
# 9      400012     Mahārāshtra
# 10        NaN             NaN
# 11        NaN  Madhya Pradesh
# 12        NaN             NaN
# 13        NaN     Mahārāshtra
# 14        NaN     Mahārāshtra
# 15        NaN     Mahārāshtra
# 16        NaN             NaN
# 17     400005     Mahārāshtra
# 18        NaN             NaN
# 19     400037     Mahārāshtra
# 20        NaN     Mahārāshtra
# 21        NaN             NaN
# 22        NaN             NaN
# 23        NaN             NaN
# 24        NaN             NaN
# 25    400 028     Mahārāshtra
# 26        NaN     Mahārāshtra
# 27     400006     Mahārāshtra
# 28        NaN             NaN
# 29        NaN     Mahārāshtra

# %%
# delete rows with none values
clean_park_dataframe3 = clean_park_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
clean_park_dataframe3
# Out:
#                                name                                categories  \
# 0   Harish Mahindra Children's Park                                      Park
# 1         Traditions at Reagan Park                                Conference
# 3                       Rivali Park                        Real Estate Office
# 4                Priyadarshini Park                                      Park
# 5                       Park Avenue                               Men's Store
# 6          Peninsula Corporate Park                                  Building
# 9                  One Avighna Park                       Housing Development
# 17                     Badhwar Park  Residential Building (Apartment / Condo)
# 19                      Bhakti Park                       Housing Development
# 25                     Shivaji Park                                Playground
# 27                        Hill Park  Residential Building (Apartment / Condo)
#
#                                               address        lat        lng  \
# 0            Breach Candy, Behind American Counsulate  18.914867  72.823688
# 1                                 1176 Kingwood Drive  18.949804  72.834699
# 3   Rivali Park, Western Express Highway,Borivali ...  18.929599  72.828181
# 4                                     Nepean Sea Road  18.957515  72.799614
# 5   Shop No. 32/34, Churchgate House, Veer Nariman...  18.920214  72.830151
# 6                                         Lower Parel  18.998626  72.825408
# 9                           Mahadev Palav Marg, Parel  18.994041  72.834806
# 17                                             Colaba  18.918839  72.828051
# 19                                   Near Imax Adlabs  19.027670  72.880010
# 25                      Swatantrya Veer Savarkar Marg  19.026621  72.841033
# 27                                       Malabar Hill  18.951897  72.799129
#
#    postalCode        state
# 0      400026  Mahārāshtra
# 1       46123      Indiana
# 3      400066  Mahārāshtra
# 4      400006  Mahārāshtra
# 5      400001  Mahārāshtra
# 6      400013  Mahārāshtra
# 9      400012  Mahārāshtra
# 17     400005  Mahārāshtra
# 19     400037  Mahārāshtra
# 25    400 028  Mahārāshtra
# 27     400006  Mahārāshtra

# %%
# delete rows which its category is not Park
df_park = clean_park_dataframe3[clean_park_dataframe3.categories == 'Park']
df_park
# Out:
#                               name categories  \
# 0  Harish Mahindra Children's Park       Park
# 4               Priyadarshini Park       Park
#
#                                     address        lat        lng postalCode  \
# 0  Breach Candy, Behind American Counsulate  18.914867  72.823688     400026
# 4                           Nepean Sea Road  18.957515  72.799614     400006
#
#          state
# 0  Mahārāshtra
# 4  Mahārāshtra

# %%
#Restaurants

# %%
# search for Restaurants
search_query = 'Restaurant'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KL3RTTROV0N33KJKSUK0MKY4D12LIQDWUIOHX10M4OBHVH34&client_secret=P45QAU0PNKG4WX1PVNVTGZUP2ZU1ZRNYAMA33HJKSQZJUBF1&ll=18.9387711,72.8353355&v=20180604&query=Restaurant&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
Rresults = requests.get(url).json()
#Rresults

# %%
# assign relevant part of JSON to venues
venues = Rresults['response']['venues']

# tranform venues into a dataframe
Restaurant_dataframe = json_normalize(venues)
Restaurant_dataframe.head()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                               name  \
# 0  5263f0f5498edc1ad5f3270f  Nanumal Bhojraj Restaurant - Fort
# 1  4e4c0a4122713bd908c641ff                 Farhang Restaurant
# 2  4fb5276be4b0b34b9ac27a1b               Iran Like Restaurant
# 3  4d9f2bfe9b91a1cda6c365c0            New Majestic Restaurant
# 4  4f489f23e4b018635344413a        Panchratna restaurant & bar
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1590405165    False
# 1  [{'id': '4bf58dd8d48988d1cc941735', 'name': 'S...  v-1590405165    False
# 2  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1590405165    False
# 3  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1590405165    False
# 4  [{'id': '4bf58dd8d48988d10f941735', 'name': 'I...  v-1590405165    False
#
#               location.address  location.crossStreet  location.lat  \
# 0           Near GPO, Fort, VT  S. Bhagat Singh Road     18.937974
# 1                 Opposite GPO        Ballard Estate     18.938165
# 2  Palton Road, Near Haj House                   NaN     18.945343
# 3                      Opp CST                   NaN     18.938972
# 4            Opp. Metro Cinema          Marine Lines     18.942900
#
#    location.lng                            location.labeledLatLngs  \
# 0     72.837663  [{'label': 'display', 'lat': 18.93797448587734...
# 1     72.837917  [{'label': 'display', 'lat': 18.93816453050136...
# 2     72.836809  [{'label': 'display', 'lat': 18.94534293649397...
# 3     72.835517  [{'label': 'display', 'lat': 18.93897156089674...
# 4     72.826820  [{'label': 'display', 'lat': 18.94289961203775...
#
#    location.distance location.postalCode location.cc location.city  \
# 0                260              400001          IN        Mumbai
# 1                280                 NaN          IN        Mumbai
# 2                747              400001          IN        Mumbai
# 3                 29                 NaN          IN        Mumbai
# 4               1007                 NaN          IN        Mumbai
#
#   location.state location.country  \
# 0    Mahārāshtra            India
# 1    Mahārāshtra            India
# 2    Mahārāshtra            India
# 3    Mahārāshtra            India
# 4    Mahārāshtra            India
#
#                            location.formattedAddress
# 0  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...
# 1  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...
# 2  [Palton Road, Near Haj House, Mumbai 400001, M...
# 3              [Opp CST, Mumbai, Mahārāshtra, India]
# 4  [Opp. Metro Cinema (Marine Lines), Mumbai, Mah...

# %%
# keep only columns that include venue name, and anything that is associated with location
Restaurant_clean_columns = ['name', 'categories'] + [col for col in Restaurant_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Restaurant_dataframe = Restaurant_dataframe.loc[:,Restaurant_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list3 = row['categories']
    except:
        categories_list3 = row['venue.categories']
        
    if len(categories_list3) == 0:
        return None
    else:
        return categories_list3[0]['name']

# filter the category for each row
clean_Restaurant_dataframe['categories'] = clean_Restaurant_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Restaurant_dataframe.columns = [column.split('.')[-1] for column in clean_Restaurant_dataframe.columns]

clean_Restaurant_dataframe.head()
# Out:
#                                 name         categories  \
# 0  Nanumal Bhojraj Restaurant - Fort  Indian Restaurant
# 1                 Farhang Restaurant         Steakhouse
# 2               Iran Like Restaurant  Indian Restaurant
# 3            New Majestic Restaurant  Indian Restaurant
# 4        Panchratna restaurant & bar  Indian Restaurant
#
#                        address           crossStreet        lat        lng  \
# 0           Near GPO, Fort, VT  S. Bhagat Singh Road  18.937974  72.837663
# 1                 Opposite GPO        Ballard Estate  18.938165  72.837917
# 2  Palton Road, Near Haj House                   NaN  18.945343  72.836809
# 3                      Opp CST                   NaN  18.938972  72.835517
# 4            Opp. Metro Cinema          Marine Lines  18.942900  72.826820
#
#                                       labeledLatLngs  distance postalCode  cc  \
# 0  [{'label': 'display', 'lat': 18.93797448587734...       260     400001  IN
# 1  [{'label': 'display', 'lat': 18.93816453050136...       280        NaN  IN
# 2  [{'label': 'display', 'lat': 18.94534293649397...       747     400001  IN
# 3  [{'label': 'display', 'lat': 18.93897156089674...        29        NaN  IN
# 4  [{'label': 'display', 'lat': 18.94289961203775...      1007        NaN  IN
#
#      city        state country  \
# 0  Mumbai  Mahārāshtra   India
# 1  Mumbai  Mahārāshtra   India
# 2  Mumbai  Mahārāshtra   India
# 3  Mumbai  Mahārāshtra   India
# 4  Mumbai  Mahārāshtra   India
#
#                                     formattedAddress                        id
# 0  [Near GPO, Fort, VT (S. Bhagat Singh Road), Mu...  5263f0f5498edc1ad5f3270f
# 1  [Opposite GPO (Ballard Estate), Mumbai, Mahārā...  4e4c0a4122713bd908c641ff
# 2  [Palton Road, Near Haj House, Mumbai 400001, M...  4fb5276be4b0b34b9ac27a1b
# 3              [Opp CST, Mumbai, Mahārāshtra, India]  4d9f2bfe9b91a1cda6c365c0
# 4  [Opp. Metro Cinema (Marine Lines), Mumbai, Mah...  4f489f23e4b018635344413a

# %%
# delete unnecessary columns
clean_Restaurant_dataframe2= clean_Restaurant_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Restaurant_dataframe2
# Out:
#                                           name            categories  \
# 0            Nanumal Bhojraj Restaurant - Fort     Indian Restaurant
# 1                           Farhang Restaurant            Steakhouse
# 2                         Iran Like Restaurant     Indian Restaurant
# 3                      New Majestic Restaurant     Indian Restaurant
# 4                  Panchratna restaurant & bar     Indian Restaurant
# 5                  Stadium Restaurant & Stores     Indian Restaurant
# 6                         Sai Pooja Restaurant                  None
# 7                            Poonam Restaurant            Restaurant
# 8                              Aram Restaurant      Asian Restaurant
# 9   Nanumal Bhojraj Restaurant - Masjid Bunder     Indian Restaurant
# 10                          Kalpana restaurant                  None
# 11                          Kamat's Restaurant     Indian Restaurant
# 12                          Gulshan Restaurant     Indian Restaurant
# 13                Sind Punjab Bar & Restaurant            Restaurant
# 14                   Mangalore naaz Restaurant      Asian Restaurant
# 15                           Bombay Restaurant     Indian Restaurant
# 16                           Canara Restaurant     Indian Restaurant
# 17                    Anubhav Restaurant & Bar     Indian Restaurant
# 18                            Lalit restaurant                   Bar
# 19                           Kayani Restaurant            Irani Cafe
# 20                         Goodluck Restaurant                  None
# 21                             Pine Restaurant     Indian Restaurant
# 22                      Excellensea Restaurant             BBQ Joint
# 23                      Royal China Restaurant  Cantonese Restaurant
# 24                         National Restaurant                  Food
# 25                         Brighton Restaurant            Restaurant
# 26                     Golden Wheel Restaurant            Restaurant
# 27                Fountain Sizzlers Restaurant            Steakhouse
# 28                          Welcome Restaurant     Indian Restaurant
# 29                             Fort restaurant                  None
#
#                                               address        lat        lng  \
# 0                                  Near GPO, Fort, VT  18.937974  72.837663
# 1                                        Opposite GPO  18.938165  72.837917
# 2                         Palton Road, Near Haj House  18.945343  72.836809
# 3                                             Opp CST  18.938972  72.835517
# 4                                   Opp. Metro Cinema  18.942900  72.826820
# 5                                   Veer Nariman Road  18.933173  72.826929
# 6                                                 NaN  18.938357  72.835073
# 7                                                 NaN  18.939225  72.835707
# 8                           Capitol building, DN Road  18.939543  72.834495
# 9   Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 10                                                Gpo  18.937489  72.836157
# 11                        Opp. Electric House, Colaba  18.921570  72.831004
# 12                                                NaN  18.938199  72.837764
# 13                        263, SBS Road, Fort, Mumbai  18.937048  72.837381
# 14                                                NaN  18.937245  72.837606
# 15                                                NaN  18.935902  72.834426
# 16                                                NaN  18.936847  72.837525
# 17                                                NaN  18.936497  72.837586
# 18                                 Cawasji Patel road  18.935002  72.833791
# 19                                                NaN  18.935040  72.836941
# 20                                                NaN  18.935578  72.837357
# 21                        Nawab Tank Bunder, Dockyard  18.964799  72.844015
# 22                                          Mint Road  18.935266  72.837240
# 23                                                NaN  18.937876  72.831005
# 24                                    opp fort market  18.935112  72.836896
# 25                                                NaN  18.935007  72.833687
# 26                                            Girgaon  18.954636  72.819690
# 27                             57 Mahatma Gandhi Road  18.931366  72.831462
# 28                                                NaN  18.942531  72.831328
# 29                                               Fort  18.933971  72.833605
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1         NaN  Mahārāshtra
# 2      400001  Mahārāshtra
# 3         NaN  Mahārāshtra
# 4         NaN  Mahārāshtra
# 5      400023  Mahārāshtra
# 6         NaN  Mahārāshtra
# 7         NaN          NaN
# 8         NaN  Mahārāshtra
# 9      400009  Mahārāshtra
# 10        NaN  Mahārāshtra
# 11        NaN  Mahārāshtra
# 12     400001  Mahārāshtra
# 13        NaN          NaN
# 14        NaN          NaN
# 15        NaN  Mahārāshtra
# 16        NaN          NaN
# 17     400001  Mahārāshtra
# 18     400001  Mahārāshtra
# 19        NaN          NaN
# 20        NaN  Mahārāshtra
# 21     400010  Mahārāshtra
# 22     400001  Mahārāshtra
# 23        NaN          NaN
# 24     400001  Mahārāshtra
# 25        NaN          NaN
# 26        NaN  Mahārāshtra
# 27    400 023  Mahārāshtra
# 28        NaN          NaN
# 29        NaN  Mahārāshtra

# %%
# delete rows with none values
df_Restaurant = clean_Restaurant_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Restaurant
# Out:
#                                           name         categories  \
# 0            Nanumal Bhojraj Restaurant - Fort  Indian Restaurant
# 2                         Iran Like Restaurant  Indian Restaurant
# 5                  Stadium Restaurant & Stores  Indian Restaurant
# 9   Nanumal Bhojraj Restaurant - Masjid Bunder  Indian Restaurant
# 18                            Lalit restaurant                Bar
# 21                             Pine Restaurant  Indian Restaurant
# 22                      Excellensea Restaurant          BBQ Joint
# 24                         National Restaurant               Food
# 27                Fountain Sizzlers Restaurant         Steakhouse
#
#                                               address        lat        lng  \
# 0                                  Near GPO, Fort, VT  18.937974  72.837663
# 2                         Palton Road, Near Haj House  18.945343  72.836809
# 5                                   Veer Nariman Road  18.933173  72.826929
# 9   Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 18                                 Cawasji Patel road  18.935002  72.833791
# 21                        Nawab Tank Bunder, Dockyard  18.964799  72.844015
# 22                                          Mint Road  18.935266  72.837240
# 24                                    opp fort market  18.935112  72.836896
# 27                             57 Mahatma Gandhi Road  18.931366  72.831462
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 2      400001  Mahārāshtra
# 5      400023  Mahārāshtra
# 9      400009  Mahārāshtra
# 18     400001  Mahārāshtra
# 21     400010  Mahārāshtra
# 22     400001  Mahārāshtra
# 24     400001  Mahārāshtra
# 27    400 023  Mahārāshtra

# %%
#Cafeteria

# %%
# search for Cafeteria
search_query = 'Cafeteria'
radius = 10000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KL3RTTROV0N33KJKSUK0MKY4D12LIQDWUIOHX10M4OBHVH34&client_secret=P45QAU0PNKG4WX1PVNVTGZUP2ZU1ZRNYAMA33HJKSQZJUBF1&ll=18.9387711,72.8353355&v=20180604&query=Cafeteria&radius=10000&limit=30'

# %%
# Send the GET Request and examine the results
cresults = requests.get(url).json()
#cresults

# %%
# assign relevant part of JSON to venues
venues = cresults['response']['venues']

# tranform venues into a dataframe
Cafeteria_dataframe = json_normalize(venues)
Cafeteria_dataframe.head()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                         name  \
# 0  4e81776030f86985e40abb54                    Cafeteria
# 1  50050da9e4b0d73a8dfa7ee9    Cafeteria at Tata Capital
# 2  4e2943f02271752a459cb122  Mumbai High Court Cafeteria
# 3  4bdfcc5affdec9286e31eda1   Cafeteria at Indian Hotels
# 4  4d53497cd4a6721ec05589ac                    Cafeteria
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d16d941735', 'name': 'C...  v-1590405168    False
# 1  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1590405168    False
# 2  [{'id': '4bf58dd8d48988d120951735', 'name': 'F...  v-1590405168    False
# 3                                                 []  v-1590405168    False
# 4                                                 []  v-1590405168    False
#
#          location.address  location.lat  location.lng  \
# 0   Breach Candy Hospital     18.971833     72.804981
# 1              One Forbes     18.930769     72.835434
# 2                    Fort     18.933198     72.829170
# 3           Oxford Towers     18.922937     72.832849
# 4  Mumbai central station     18.970839     72.820636
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.97183316652913...               4874
# 1  [{'label': 'display', 'lat': 18.930769, 'lng':...                890
# 2  [{'label': 'display', 'lat': 18.93319755884302...                898
# 3  [{'label': 'display', 'lat': 18.922937, 'lng':...               1781
# 4  [{'label': 'display', 'lat': 18.97083858982881...               3890
#
#   location.postalCode location.cc location.city location.state  \
# 0              400026          IN        Mumbai    Mahārāshtra
# 1                 NaN          IN        Mumbai    Mahārāshtra
# 2                 NaN          IN        Mumbai    Mahārāshtra
# 3                 NaN          IN           NaN    Mahārāshtra
# 4                 NaN          IN        Mumbai    Mahārāshtra
#
#   location.country                          location.formattedAddress  \
# 0            India  [Breach Candy Hospital, Mumbai 400026, Mahārās...
# 1            India  [One Forbes (Kala Ghoda), Mumbai, Mahārāshtra,...
# 2            India                 [Fort, Mumbai, Mahārāshtra, India]
# 3            India                [Oxford Towers, Mahārāshtra, India]
# 4            India  [Mumbai central station, Mumbai, Mahārāshtra, ...
#
#   location.crossStreet
# 0                  NaN
# 1           Kala Ghoda
# 2                  NaN
# 3                  NaN
# 4                  NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
Cafeteria_clean_columns = ['name', 'categories'] + [col for col in Cafeteria_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Cafeteria_dataframe = Cafeteria_dataframe.loc[:,Cafeteria_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list4 = row['categories']
    except:
        categories_list4 = row['venue.categories']
        
    if len(categories_list4) == 0:
        return None
    else:
        return categories_list4[0]['name']

# filter the category for each row
clean_Cafeteria_dataframe['categories'] = clean_Cafeteria_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Cafeteria_dataframe.columns = [column.split('.')[-1] for column in clean_Cafeteria_dataframe.columns]

clean_Cafeteria_dataframe.head()
# Out:
#                           name  categories                 address        lat  \
# 0                    Cafeteria        Café   Breach Candy Hospital  18.971833
# 1    Cafeteria at Tata Capital  Food Court              One Forbes  18.930769
# 2  Mumbai High Court Cafeteria  Food Court                    Fort  18.933198
# 3   Cafeteria at Indian Hotels        None           Oxford Towers  18.922937
# 4                    Cafeteria        None  Mumbai central station  18.970839
#
#          lng                                     labeledLatLngs  distance  \
# 0  72.804981  [{'label': 'display', 'lat': 18.97183316652913...      4874
# 1  72.835434  [{'label': 'display', 'lat': 18.930769, 'lng':...       890
# 2  72.829170  [{'label': 'display', 'lat': 18.93319755884302...       898
# 3  72.832849  [{'label': 'display', 'lat': 18.922937, 'lng':...      1781
# 4  72.820636  [{'label': 'display', 'lat': 18.97083858982881...      3890
#
#   postalCode  cc    city        state country  \
# 0     400026  IN  Mumbai  Mahārāshtra   India
# 1        NaN  IN  Mumbai  Mahārāshtra   India
# 2        NaN  IN  Mumbai  Mahārāshtra   India
# 3        NaN  IN     NaN  Mahārāshtra   India
# 4        NaN  IN  Mumbai  Mahārāshtra   India
#
#                                     formattedAddress crossStreet  \
# 0  [Breach Candy Hospital, Mumbai 400026, Mahārās...         NaN
# 1  [One Forbes (Kala Ghoda), Mumbai, Mahārāshtra,...  Kala Ghoda
# 2                 [Fort, Mumbai, Mahārāshtra, India]         NaN
# 3                [Oxford Towers, Mahārāshtra, India]         NaN
# 4  [Mumbai central station, Mumbai, Mahārāshtra, ...         NaN
#
#                          id
# 0  4e81776030f86985e40abb54
# 1  50050da9e4b0d73a8dfa7ee9
# 2  4e2943f02271752a459cb122
# 3  4bdfcc5affdec9286e31eda1
# 4  4d53497cd4a6721ec05589ac

# %%
# delete unnecessary columns
clean_Cafeteria_dataframe2= clean_Cafeteria_dataframe.drop(['cc', 'city', 'country', 'crossStreet', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Cafeteria_dataframe2
# Out:
#                                         name                 categories  \
# 0                                  Cafeteria                       Café
# 1                  Cafeteria at Tata Capital                 Food Court
# 2                Mumbai High Court Cafeteria                 Food Court
# 3                 Cafeteria at Indian Hotels                       None
# 4                                  Cafeteria                       None
# 5   KES College of Commerce & Arts Cafeteria          College Cafeteria
# 6                    Cafeteria - P2 Building                  Cafeteria
# 7                   Cafeteria, Lodha Excelus                  Cafeteria
# 8                  Burhani College Cafeteria          College Cafeteria
# 9                              G2W Cafeteria                  Cafeteria
# 10                       Jan Ahaar Cafeteria                      Diner
# 11                          Jai Hind College  College Academic Building
# 12                           Essar Cafeteria                       Food
# 13                     Leo Burnett Cafeteria                  Cafeteria
# 14        Empire Cafeteria (Siddhi caterers)                       Café
# 15                    Ashok Towers Cafeteria                       Café
# 16                    Adfactors PR Cafeteria                     Buffet
# 17                 Mahindra Towers Cafeteria                  Cafeteria
# 18               Mahindra Holidays Cafeteria                Snack Place
# 19                           burhani college      College Arts Building
# 20                   VIT Executive Cafeteria          College Cafeteria
# 21                       welingkar cafeteria                  Cafeteria
# 22        Price Waterhouse Coopers cafeteria                       Café
# 23                         Leo Burnett India                     Office
# 24                             Bloomberg UTV                 Food Court
# 25                         Indigo Consulting                   Building
# 26                              BloombergUTV                 Food Court
# 27                                Network 18                     Office
#
#                                               address        lat        lng  \
# 0                               Breach Candy Hospital  18.971833  72.804981
# 1                                          One Forbes  18.930769  72.835434
# 2                                                Fort  18.933198  72.829170
# 3                                       Oxford Towers  18.922937  72.832849
# 4                              Mumbai central station  18.970839  72.820636
# 5                                         Parekh lane  18.948587  72.829424
# 6                            Next to Phoenix Building  18.992866  72.823965
# 7                           9th Floor, Lodha Excelus,  18.994027  72.834380
# 8                           Opp St Mary's School ICSE  18.964665  72.843831
# 9                                                 NaN  18.974342  72.813182
# 10                             Mumbai Central Station  18.975868  72.823434
# 11                                 A Road, Churchgate  18.934689  72.824822
# 12                                                NaN  18.979570  72.819515
# 13                                     36-A Big Apple  18.998785  72.840376
# 14               Empire Mills Compound, Tulsi Pipe Rd  19.000831  72.828339
# 15                                       Ashok Towers  18.997597  72.837888
# 16                                                NaN  19.005008  72.826450
# 17                                              Worli  19.006044  72.820630
# 18  Mahindra Holidays, Mahindra Towers, G.M. Bhosl...  19.005692  72.822309
# 19                                           Mazagoan  18.970446  72.835390
# 20                Vidyalankar Institute Of Technology  19.021675  72.870364
# 21                                                NaN  19.025060  72.850341
# 22                                                NaN  19.030498  72.838367
# 23                                                NaN  18.998824  72.840360
# 24                                                NaN  18.996877  72.819759
# 25                                      The Big Apple  18.998891  72.840350
# 26            Parijaat House, 1076, Dr. E Moses Road,  18.996397  72.819472
# 27                New Empire Complex, Lower Parel (w)  19.031835  72.845926
#
#    postalCode        state
# 0      400026  Mahārāshtra
# 1         NaN  Mahārāshtra
# 2         NaN  Mahārāshtra
# 3         NaN  Mahārāshtra
# 4         NaN  Mahārāshtra
# 5      400067  Mahārāshtra
# 6      400013  Mahārāshtra
# 7      400011  Mahārāshtra
# 8         NaN  Mahārāshtra
# 9         NaN          NaN
# 10        NaN          NaN
# 11    400 020  Mahārāshtra
# 12        NaN  Mahārāshtra
# 13     400012  Mahārāshtra
# 14        NaN  Mahārāshtra
# 15        NaN  Mahārāshtra
# 16        NaN          NaN
# 17     400030  Mahārāshtra
# 18     400018  Mahārāshtra
# 19     400010  Mahārāshtra
# 20     400037  Mahārāshtra
# 21        NaN          NaN
# 22        NaN          NaN
# 23        NaN          NaN
# 24        NaN          NaN
# 25     400012  Mahārāshtra
# 26     400018  Mahārāshtra
# 27        NaN  Mahārāshtra

# %%
# delete rows with none values
df_Cafeteria = clean_Cafeteria_dataframe2.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
df_Cafeteria
# Out:
#                                         name                 categories  \
# 0                                  Cafeteria                       Café
# 5   KES College of Commerce & Arts Cafeteria          College Cafeteria
# 6                    Cafeteria - P2 Building                  Cafeteria
# 7                   Cafeteria, Lodha Excelus                  Cafeteria
# 11                          Jai Hind College  College Academic Building
# 13                     Leo Burnett Cafeteria                  Cafeteria
# 17                 Mahindra Towers Cafeteria                  Cafeteria
# 18               Mahindra Holidays Cafeteria                Snack Place
# 19                           burhani college      College Arts Building
# 20                   VIT Executive Cafeteria          College Cafeteria
# 25                         Indigo Consulting                   Building
# 26                              BloombergUTV                 Food Court
#
#                                               address        lat        lng  \
# 0                               Breach Candy Hospital  18.971833  72.804981
# 5                                         Parekh lane  18.948587  72.829424
# 6                            Next to Phoenix Building  18.992866  72.823965
# 7                           9th Floor, Lodha Excelus,  18.994027  72.834380
# 11                                 A Road, Churchgate  18.934689  72.824822
# 13                                     36-A Big Apple  18.998785  72.840376
# 17                                              Worli  19.006044  72.820630
# 18  Mahindra Holidays, Mahindra Towers, G.M. Bhosl...  19.005692  72.822309
# 19                                           Mazagoan  18.970446  72.835390
# 20                Vidyalankar Institute Of Technology  19.021675  72.870364
# 25                                      The Big Apple  18.998891  72.840350
# 26            Parijaat House, 1076, Dr. E Moses Road,  18.996397  72.819472
#
#    postalCode        state
# 0      400026  Mahārāshtra
# 5      400067  Mahārāshtra
# 6      400013  Mahārāshtra
# 7      400011  Mahārāshtra
# 11    400 020  Mahārāshtra
# 13     400012  Mahārāshtra
# 17     400030  Mahārāshtra
# 18     400018  Mahārāshtra
# 19     400010  Mahārāshtra
# 20     400037  Mahārāshtra
# 25     400012  Mahārāshtra
# 26     400018  Mahārāshtra

# %%
#Shopping

# %%
# search for Shopping
search_query = 'Shopping'
radius = 1000

# Define the corresponding URL
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(ClIENT_ID, ClIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KL3RTTROV0N33KJKSUK0MKY4D12LIQDWUIOHX10M4OBHVH34&client_secret=P45QAU0PNKG4WX1PVNVTGZUP2ZU1ZRNYAMA33HJKSQZJUBF1&ll=18.9387711,72.8353355&v=20180604&query=Shopping&radius=1000&limit=30'

# %%
# Send the GET Request and examine the results
sresults = requests.get(url).json()
#sresults

# %%
# assign relevant part of JSON to venues
venues = sresults['response']['venues']

# tranform venues into a dataframe
Shopping_dataframe = json_normalize(venues)
Shopping_dataframe.head()
# Out:
# C:\Users\Acer\anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   """
#                          id                       name  \
# 0  4e54cc34ae60e3d6b7f18c28     Ashoka Shopping Centre
# 1  527b9fd8498e3c08ce24052d    Ashrafi Shopping Centre
# 2  4ecf3a6ce5faa5ec01659919  Bhangwadi Shopping Arcade
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1590405170    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1590405170    False
# 2  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1590405170    False
#
#    location.lat  location.lng  \
# 0     18.945182     72.832121
# 1     18.948688     72.836013
# 2     18.946791     72.827999
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 18.94518213019515...                789
# 1  [{'label': 'display', 'lat': 18.9486880047746,...               1106
# 2  [{'label': 'display', 'lat': 18.94679133422852...               1180
#
#   location.cc location.city location.state location.country  \
# 0          IN        Mumbai    Mahārāshtra            India
# 1          IN           NaN            NaN            India
# 2          IN           NaN            NaN            India
#
#       location.formattedAddress
# 0  [Mumbai, Mahārāshtra, India]
# 1                       [India]
# 2                       [India]

# %%
# keep only columns that include venue name, and anything that is associated with location
Shopping_clean_columns = ['name', 'categories'] + [col for col in Shopping_dataframe.columns if col.startswith('location.')]+ ['id']
clean_Shopping_dataframe = Shopping_dataframe.loc[:,Shopping_clean_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list5 = row['categories']
    except:
        categories_list5 = row['venue.categories']
        
    if len(categories_list5) == 0:
        return None
    else:
        return categories_list5[0]['name']

# filter the category for each row
clean_Shopping_dataframe['categories'] = clean_Shopping_dataframe.apply(get_category_type, axis=1)

# clean column names by keeping only last term
clean_Shopping_dataframe.columns = [column.split('.')[-1] for column in clean_Shopping_dataframe.columns]

clean_Shopping_dataframe.head()
# Out:
#                         name categories        lat        lng  \
# 0     Ashoka Shopping Centre     Office  18.945182  72.832121
# 1    Ashrafi Shopping Centre     Office  18.948688  72.836013
# 2  Bhangwadi Shopping Arcade     Office  18.946791  72.827999
#
#                                       labeledLatLngs  distance  cc    city  \
# 0  [{'label': 'display', 'lat': 18.94518213019515...       789  IN  Mumbai
# 1  [{'label': 'display', 'lat': 18.9486880047746,...      1106  IN     NaN
# 2  [{'label': 'display', 'lat': 18.94679133422852...      1180  IN     NaN
#
#          state country              formattedAddress                        id
# 0  Mahārāshtra   India  [Mumbai, Mahārāshtra, India]  4e54cc34ae60e3d6b7f18c28
# 1          NaN   India                       [India]  527b9fd8498e3c08ce24052d
# 2          NaN   India                       [India]  4ecf3a6ce5faa5ec01659919

# %%
# delete unnecessary columns
clean_Shopping_dataframe2= clean_Shopping_dataframe.drop(['cc', 'city', 'country', 'distance', 'formattedAddress',\
                                        'labeledLatLngs', 'id'], axis=1)
clean_Shopping_dataframe2
# Out:
#                         name categories        lat        lng        state
# 0     Ashoka Shopping Centre     Office  18.945182  72.832121  Mahārāshtra
# 1    Ashrafi Shopping Centre     Office  18.948688  72.836013          NaN
# 2  Bhangwadi Shopping Arcade     Office  18.946791  72.827999          NaN

# %%
# create dataframe of hotels, shopping stores and Cafeteria

# %%
hotel_neighbourhood_df = pd.concat([df_hotel, df_Cafeteria, df_Shopping], ignore_index=True)
hotel_neighbourhood_df
# Out:
#                                         name                 categories  \
# 0                            Residency Hotel                      Hotel
# 1                             Benazeer Hotel                      Hotel
# 2                                  Cafeteria                       Café
# 3   KES College of Commerce & Arts Cafeteria          College Cafeteria
# 4                    Cafeteria - P2 Building                  Cafeteria
# 5                   Cafeteria, Lodha Excelus                  Cafeteria
# 6                           Jai Hind College  College Academic Building
# 7                      Leo Burnett Cafeteria                  Cafeteria
# 8                  Mahindra Towers Cafeteria                  Cafeteria
# 9                Mahindra Holidays Cafeteria                Snack Place
# 10                           burhani college      College Arts Building
# 11                   VIT Executive Cafeteria          College Cafeteria
# 12                         Indigo Consulting                   Building
# 13                              BloombergUTV                 Food Court
#
#                                               address        lat        lng  \
# 0   26, Corner of D.N. Road and Rustom Sidhwa Marg...  18.934978  72.833481
# 1                                    16 Gunbow Street  18.935140  72.833948
# 2                               Breach Candy Hospital  18.971833  72.804981
# 3                                         Parekh lane  18.948587  72.829424
# 4                            Next to Phoenix Building  18.992866  72.823965
# 5                           9th Floor, Lodha Excelus,  18.994027  72.834380
# 6                                  A Road, Churchgate  18.934689  72.824822
# 7                                      36-A Big Apple  18.998785  72.840376
# 8                                               Worli  19.006044  72.820630
# 9   Mahindra Holidays, Mahindra Towers, G.M. Bhosl...  19.005692  72.822309
# 10                                           Mazagoan  18.970446  72.835390
# 11                Vidyalankar Institute Of Technology  19.021675  72.870364
# 12                                      The Big Apple  18.998891  72.840350
# 13            Parijaat House, 1076, Dr. E Moses Road,  18.996397  72.819472
#
#    postalCode        state
# 0      400001  Mahārāshtra
# 1      400001  Mahārāshtra
# 2      400026  Mahārāshtra
# 3      400067  Mahārāshtra
# 4      400013  Mahārāshtra
# 5      400011  Mahārāshtra
# 6     400 020  Mahārāshtra
# 7      400012  Mahārāshtra
# 8      400030  Mahārāshtra
# 9      400018  Mahārāshtra
# 10     400010  Mahārāshtra
# 11     400037  Mahārāshtra
# 12     400012  Mahārāshtra
# 13     400018  Mahārāshtra

# %%
# Generate map to visualize hotel neighbourhood including shopping stores and Cafeteria

# %%
hotel_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(hotel_neighbourhood_df['lat'], hotel_neighbourhood_df['lng'], 
                                           hotel_neighbourhood_df['name'], hotel_neighbourhood_df['categories'],\
                                               hotel_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(hotel_map)  
    
hotel_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
 #create dataframe of Park, Restaurant and Cafeteria

# %%
park_neighbourhood_df = pd.concat([df_park, df_Restaurant, df_Cafeteria,], ignore_index=True)
park_neighbourhood_df
# Out:
#                                           name                 categories  \
# 0              Harish Mahindra Children's Park                       Park
# 1                           Priyadarshini Park                       Park
# 2            Nanumal Bhojraj Restaurant - Fort          Indian Restaurant
# 3                         Iran Like Restaurant          Indian Restaurant
# 4                  Stadium Restaurant & Stores          Indian Restaurant
# 5   Nanumal Bhojraj Restaurant - Masjid Bunder          Indian Restaurant
# 6                             Lalit restaurant                        Bar
# 7                              Pine Restaurant          Indian Restaurant
# 8                       Excellensea Restaurant                  BBQ Joint
# 9                          National Restaurant                       Food
# 10                Fountain Sizzlers Restaurant                 Steakhouse
# 11                                   Cafeteria                       Café
# 12    KES College of Commerce & Arts Cafeteria          College Cafeteria
# 13                     Cafeteria - P2 Building                  Cafeteria
# 14                    Cafeteria, Lodha Excelus                  Cafeteria
# 15                            Jai Hind College  College Academic Building
# 16                       Leo Burnett Cafeteria                  Cafeteria
# 17                   Mahindra Towers Cafeteria                  Cafeteria
# 18                 Mahindra Holidays Cafeteria                Snack Place
# 19                             burhani college      College Arts Building
# 20                     VIT Executive Cafeteria          College Cafeteria
# 21                           Indigo Consulting                   Building
# 22                                BloombergUTV                 Food Court
#
#                                               address        lat        lng  \
# 0            Breach Candy, Behind American Counsulate  18.914867  72.823688
# 1                                     Nepean Sea Road  18.957515  72.799614
# 2                                  Near GPO, Fort, VT  18.937974  72.837663
# 3                         Palton Road, Near Haj House  18.945343  72.836809
# 4                                   Veer Nariman Road  18.933173  72.826929
# 5   Gaumukh Bhawan, Masjid Bunder West, Near Masji...  18.953200  72.837577
# 6                                  Cawasji Patel road  18.935002  72.833791
# 7                         Nawab Tank Bunder, Dockyard  18.964799  72.844015
# 8                                           Mint Road  18.935266  72.837240
# 9                                     opp fort market  18.935112  72.836896
# 10                             57 Mahatma Gandhi Road  18.931366  72.831462
# 11                              Breach Candy Hospital  18.971833  72.804981
# 12                                        Parekh lane  18.948587  72.829424
# 13                           Next to Phoenix Building  18.992866  72.823965
# 14                          9th Floor, Lodha Excelus,  18.994027  72.834380
# 15                                 A Road, Churchgate  18.934689  72.824822
# 16                                     36-A Big Apple  18.998785  72.840376
# 17                                              Worli  19.006044  72.820630
# 18  Mahindra Holidays, Mahindra Towers, G.M. Bhosl...  19.005692  72.822309
# 19                                           Mazagoan  18.970446  72.835390
# 20                Vidyalankar Institute Of Technology  19.021675  72.870364
# 21                                      The Big Apple  18.998891  72.840350
# 22            Parijaat House, 1076, Dr. E Moses Road,  18.996397  72.819472
#
#    postalCode        state
# 0      400026  Mahārāshtra
# 1      400006  Mahārāshtra
# 2      400001  Mahārāshtra
# 3      400001  Mahārāshtra
# 4      400023  Mahārāshtra
# 5      400009  Mahārāshtra
# 6      400001  Mahārāshtra
# 7      400010  Mahārāshtra
# 8      400001  Mahārāshtra
# 9      400001  Mahārāshtra
# 10    400 023  Mahārāshtra
# 11     400026  Mahārāshtra
# 12     400067  Mahārāshtra
# 13     400013  Mahārāshtra
# 14     400011  Mahārāshtra
# 15    400 020  Mahārāshtra
# 16     400012  Mahārāshtra
# 17     400030  Mahārāshtra
# 18     400018  Mahārāshtra
# 19     400010  Mahārāshtra
# 20     400037  Mahārāshtra
# 21     400012  Mahārāshtra
# 22     400018  Mahārāshtra

# %%
park_map = folium.Map(location=[latitude, longitude], zoom_start=14)

for lat, lng, name, categories, address in zip(park_neighbourhood_df['lat'], park_neighbourhood_df['lng'], 
                                           park_neighbourhood_df['name'], park_neighbourhood_df['categories'],\
                                               park_neighbourhood_df['address']):
    label = '{}, {}'.format(name, address)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='blue',
        fill_opacity=0.7,
        parse_html=False).add_to(park_map)  
    
park_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
